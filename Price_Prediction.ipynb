# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('auto.csv')

# %%
df
# Out:
#         Price  Year        Make               Model       Mileage  Body style  \
# 0      7600.0  2021  Volkswagen                Polo   38000.00000       Սեդան
# 1     41000.0  2020  Mitsubishi              Pajero      10.00000   Ամենագնաց
# 2      6000.0  2005      Nissan               Tiida  156000.00000       Սեդան
# 3      6400.0  2006      Toyota  Land Cruiser Prado  170000.00000   Ամենագնաց
# 4     13000.0  2019     Hyundai                Kona   26035.74569   Ամենագնաց
# ...       ...   ...         ...                 ...           ...         ...
# 9462  15700.0  2018      Toyota              Tundra   19374.00000       Պիկապ
# 9463   6700.0  2018         Kia            Sportage   18347.00000   Ամենագնաց
# 9464  12300.0  2016      Toyota              Tundra   23714.00000       Պիկապ
# 9465  13500.0  2017      Toyota              Tundra   23417.00000       Պիկապ
# 9466  12700.0  2016      Toyota              Tundra   22574.00000       Պիկապ
#
#            Gearbox Hand drive   Engine         Color   Custom cleared
# 0      Մեխանիկական        Ձախ   Բենզին        Սպիտակ  Մաքսազերծված չէ
# 1          Ավտոմատ        Ձախ   Բենզին        Սպիտակ   Մաքսազերծված է
# 2          Ավտոմատ        Ձախ      Գազ     Այլ գույն   Մաքսազերծված է
# 3          Ավտոմատ        Ձախ    Դիզել            Սև  Մաքսազերծված չէ
# 4          Ավտոմատ        Ձախ   Բենզին   Արծաթագույն  Մաքսազերծված չէ
# ...            ...        ...      ...           ...              ...
# 9462       Ավտոմատ        Ձախ   Բենզին            Սև  Մաքսազերծված չէ
# 9463       Ավտոմատ        Ձախ   Բենզին   Արծաթագույն  Մաքսազերծված չէ
# 9464       Ավտոմատ        Ձախ   Բենզին    Մոխրագույն  Մաքսազերծված չէ
# 9465       Ավտոմատ        Ձախ   Բենզին        Սպիտակ  Մաքսազերծված չէ
# 9466       Ավտոմատ        Ձախ   Բենզին            Սև  Մաքսազերծված չէ
#
# [9467 rows x 11 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder
ord_enc = OrdinalEncoder()

# %%
for i in df.columns:
    if type(df[i][0]) == str:
        df[i] = ord_enc.fit_transform(df[[i]])

# %%
df
# Out:
#         Price  Year  Make  Model       Mileage  Body style  Gearbox  \
# 0      7600.0  2021  50.0  387.0   38000.00000         7.0      1.0
# 1     41000.0  2020  32.0  374.0      10.00000         0.0      0.0
# 2      6000.0  2005  33.0  494.0  156000.00000         7.0      0.0
# 3      6400.0  2006  47.0  316.0  170000.00000         0.0      0.0
# 4     13000.0  2019  19.0  304.0   26035.74569         0.0      0.0
# ...       ...   ...   ...    ...           ...         ...      ...
# 9462  15700.0  2018  47.0  503.0   19374.00000         6.0      0.0
# 9463   6700.0  2018  23.0  477.0   18347.00000         0.0      0.0
# 9464  12300.0  2016  47.0  503.0   23714.00000         6.0      0.0
# 9465  13500.0  2017  47.0  503.0   23417.00000         6.0      0.0
# 9466  12700.0  2016  47.0  503.0   22574.00000         6.0      0.0
#
#       Hand drive  Engine  Color  Custom cleared
# 0            1.0     0.0   14.0             1.0
# 1            1.0     0.0   14.0             0.0
# 2            1.0     1.0    0.0             0.0
# 3            1.0     2.0   15.0             1.0
# 4            1.0     0.0    1.0             1.0
# ...          ...     ...    ...             ...
# 9462         1.0     0.0   15.0             1.0
# 9463         1.0     0.0    1.0             1.0
# 9464         1.0     0.0    9.0             1.0
# 9465         1.0     0.0   14.0             1.0
# 9466         1.0     0.0   15.0             1.0
#
# [9467 rows x 11 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X = df.drop('Price',axis=1)

# %%
X_scaled = scaler.fit_transform(X)

# %%
y = df['Price']

# %%
y_scaled = np.log(y)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.33, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor()

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_pred , y_test)
# Out:
# 0.14206121961948423

# %%
100 - (mean_squared_error(y_pred , y_test) * 100 / y_test.mean())
# Out:
# 98.4494168847115
